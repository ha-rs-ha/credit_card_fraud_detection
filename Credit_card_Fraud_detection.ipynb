# %% [markdown]
# <a href="https://colab.research.google.com/github/ha-rs-ha/credit_card_fraud_detection/blob/main/Credit_card_Fraud_detection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

# %%
# loading the dataset to a Pandas DataFrame
credit_card_data = pd.read_csv('/content/creditcard.csv')

# %%
# first 5 rows of the dataset
credit_card_data.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
#         V26       V27       V28  Amount  Class
# 0 -0.189115  0.133558 -0.021053  149.62    0.0
# 1  0.125895 -0.008983  0.014724    2.69    0.0
# 2 -0.139097 -0.055353 -0.059752  378.66    0.0
# 3 -0.221929  0.062723  0.061458  123.50    0.0
# 4  0.502292  0.219422  0.215153   69.99    0.0
#
# [5 rows x 31 columns]

# %%
credit_card_data.tail()
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# 208030  136944.0 -2.296779  0.160723  0.029033  0.924372 -0.837166  0.988358
# 208031  136944.0 -0.813941  0.706229  0.291162 -2.623354  0.563792 -0.190741
# 208032  136944.0 -0.660347  1.147467  0.046288 -0.913694  0.741224 -1.325788
# 208033  136944.0  0.084981  0.948412 -0.343832 -0.619860  0.854294 -0.587994
# 208034  136944.0 -1.580655 -0.407163  0.677965  1.328521  1.549646 -0.563803
#
#               V7        V8        V9  ...       V21       V22       V23  \
# 208030  0.111401  1.173111 -0.304353  ...  0.295344  0.746659  0.155402
# 208031 -0.064674 -3.175029 -1.521131  ... -1.171450  0.618023 -0.012904
# 208032  1.299686 -0.297240  0.044566  ...  0.291957  0.765911 -0.373310
# 208033  0.871052  0.046588 -0.262800  ... -0.282280 -0.728923  0.117186
# 208034  0.342159  0.186344 -0.731562  ...       NaN       NaN       NaN
#
#              V24       V25       V26       V27       V28  Amount  Class
# 208030  0.194956  0.162483 -0.355256  0.491229 -0.189419  217.60    0.0
# 208031  0.706524 -0.188903 -0.571543 -0.584867 -0.286473    2.39    0.0
# 208032 -0.117641  0.191605 -0.235358 -0.150685  0.164960   21.20    0.0
# 208033  0.649924 -0.478593  0.087700  0.214288  0.075132    8.99    0.0
# 208034       NaN       NaN       NaN       NaN       NaN     NaN    NaN
#
# [5 rows x 31 columns]

# %%
# dataset informations
credit_card_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 208035 entries, 0 to 208034
# Data columns (total 31 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Time    208035 non-null  float64
#  1   V1      208035 non-null  float64
#  2   V2      208035 non-null  float64
#  3   V3      208035 non-null  float64
#  4   V4      208035 non-null  float64
#  5   V5      208035 non-null  float64
#  6   V6      208035 non-null  float64
#  7   V7      208035 non-null  float64
#  8   V8      208035 non-null  float64
#  9   V9      208035 non-null  float64
#  10  V10     208035 non-null  float64
#  11  V11     208035 non-null  float64
#  12  V12     208035 non-null  float64
#  13  V13     208035 non-null  float64
#  14  V14     208035 non-null  float64
#  15  V15     208034 non-null  float64
#  16  V16     208034 non-null  float64
#  17  V17     208034 non-null  float64
#  18  V18     208034 non-null  float64
#  19  V19     208034 non-null  float64
#  20  V20     208034 non-null  float64
#  21  V21     208034 non-null  float64
#  22  V22     208034 non-null  float64
#  23  V23     208034 non-null  float64
#  24  V24     208034 non-null  float64
#  25  V25     208034 non-null  float64
#  26  V26     208034 non-null  float64
#  27  V27     208034 non-null  float64
#  28  V28     208034 non-null  float64
#  29  Amount  208034 non-null  float64
#  30  Class   208034 non-null  float64
# dtypes: float64(31)
# memory usage: 49.2 MB

# %%
# checking the number of missing values in each column
credit_card_data.isnull().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       1
# V16       1
# V17       1
# V18       1
# V19       1
# V20       1
# V21       1
# V22       1
# V23       1
# V24       1
# V25       1
# V26       1
# V27       1
# V28       1
# Amount    1
# Class     1
# dtype: int64

# %%
# distribution of legit transactions & fraudulent transactions
credit_card_data['Class'].value_counts()
# Out:
# Class
# 0.0    207641
# 1.0       393
# Name: count, dtype: int64

# %% [markdown]
# This Dataset is highly unblanced

# %% [markdown]
# 0 --> Normal Transaction
# 1 --> fraudulent transaction

# %%
# separating the data for analysis
legit = credit_card_data[credit_card_data.Class == 0]
fraud = credit_card_data[credit_card_data.Class == 1]

# %%
print(legit.shape)
print(fraud.shape)
# Out:
# (207641, 31)
# (393, 31)

# %%
# statistical measures of the data
legit.Amount.describe()
# Out:
# count    207641.000000
# mean         89.843752
# std         247.988362
# min           0.000000
# 25%           6.000000
# 50%          23.030000
# 75%          79.540000
# max       19656.530000
# Name: Amount, dtype: float64

# %%
fraud.Amount.describe()
# Out:
# count     393.000000
# mean      123.386005
# std       257.134306
# min         0.000000
# 25%         1.000000
# 50%        12.310000
# 75%       105.890000
# max      2125.870000
# Name: Amount, dtype: float64

# %%
# compare the values for both transactions
credit_card_data.groupby('Class').mean()
# Out:
#                Time        V1        V2        V3        V4        V5  \
# Class
# 0.0    73151.716145 -0.078618 -0.009427  0.290498  0.056231 -0.087794
# 1.0    62781.541985 -5.579849  4.152674 -7.660395  4.742284 -4.017895
#
#              V6        V7        V8        V9  ...       V20       V21  \
# Class                                          ...
# 0.0    0.043980 -0.029531  0.011218  0.012859  ...  0.015750 -0.013780
# 1.0   -1.396601 -6.509509  0.663476 -2.748126  ...  0.394684  0.778507
#
#             V22       V23       V24       V25       V26       V27       V28  \
# Class
# 0.0   -0.039185 -0.013908  0.003622  0.053625  0.004850  0.000656  0.001533
# 1.0   -0.012563 -0.048989 -0.065777  0.065806  0.038768  0.180565  0.059636
#
#            Amount
# Class
# 0.0     89.843752
# 1.0    123.386005
#
# [2 rows x 30 columns]

# %% [markdown]
# Under-Sampling

# %% [markdown]
# Build a sample dataset containing similar distribution of normal transactions and Fraudulent Transactions

# %% [markdown]
# Number of Fraudulent Transactions --> 492

# %%
legit_sample = legit.sample(n=492)

# %% [markdown]
# Concatenating two DataFrames

# %%
new_dataset = pd.concat([legit_sample, fraud], axis=0)

# %%
new_dataset.head()
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# 91455    63477.0  1.255277 -0.029495 -0.427761 -0.276025  0.231572 -0.313201
# 102956   68440.0 -0.744489 -0.797113  0.841611 -1.197308 -0.228458  1.584461
# 141668   84458.0  1.249586 -0.469644  0.852798 -0.722207 -1.330126 -0.832319
# 101032   67704.0 -1.374367  0.360591  1.382047 -0.247018  0.971973 -1.209651
# 172399  121085.0  0.518281 -3.238157 -0.902286  0.072038 -1.947966 -0.095814
#
#               V7        V8        V9  ...       V21       V22       V23  \
# 91455   0.235763 -0.095670 -0.224640  ... -0.444711 -1.473184  0.016064
# 102956 -1.475569  1.034018 -3.032910  ...  0.161359  0.703665  0.138748
# 141668 -0.685765  0.064123  2.075202  ... -0.035011  0.068770 -0.022788
# 101032  0.474821 -0.173709 -0.379265  ... -0.288769 -0.877648 -0.008286
# 172399  0.035845 -0.018156  1.879957  ...  0.238414 -0.721282 -0.280999
#
#              V24       V25       V26       V27       V28  Amount  Class
# 91455  -0.820126  0.203886  0.672954 -0.115865 -0.011019   50.99    0.0
# 102956 -1.350605 -0.877216  0.080610  0.157713 -0.011177   25.00    0.0
# 141668  0.307701  0.451822 -0.677565  0.082783  0.031181    1.00    0.0
# 101032 -0.009295  0.390954  0.030655 -0.326106  0.100725    0.89    0.0
# 172399  0.133244 -0.875198  0.302690 -0.164238  0.071632  750.00    0.0
#
# [5 rows x 31 columns]

# %%
new_dataset.tail()
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# 203328  134769.0 -0.967767  2.098019 -5.222929  6.514573 -4.187674  2.114178
# 203700  134928.0  1.204934  3.238070 -6.010324  5.720847  1.548400 -2.321064
# 204064  135095.0  0.232512  0.938944 -4.647780  3.079844 -1.902655 -1.041408
# 204079  135102.0  1.862102 -0.124052 -1.989752  0.382609  0.473032 -0.674517
# 204503  135314.0 -3.158990  1.765452 -3.390168  0.987410 -1.509930 -1.280952
#
#               V7        V8        V9  ...       V21       V22       V23  \
# 203328  0.948701 -2.448427 -3.203666  ... -0.843268  0.796739  1.314312
# 203700 -0.781880  0.076619 -2.976249  ...  0.098341 -0.845866 -0.031228
# 204064 -1.020407  0.547069 -1.105990  ...  0.911373  1.042929  0.999394
# 204079  0.298621 -0.282416  0.802053  ... -0.204158 -0.511441  0.077874
# 204503 -2.719557  0.718325 -1.660183  ...  1.120533  1.605085 -0.618637
#
#              V24       V25       V26       V27       V28  Amount  Class
# 203328 -0.352887 -1.770706  0.098133  0.956769  0.162777  925.31    1.0
# 203700  0.421146  0.388361  0.056035  0.491828  0.340847    0.00    1.0
# 204064  0.901260 -0.452093  0.192959  0.180859 -0.029315  345.00    1.0
# 204079  0.388335  0.007896 -0.120980 -0.019579  0.006155  108.51    1.0
# 204503 -0.251283 -0.240528 -0.004327 -0.235477  0.018129   84.28    1.0
#
# [5 rows x 31 columns]

# %%
new_dataset['Class'].value_counts()
# Out:
# Class
# 0.0    492
# 1.0    393
# Name: count, dtype: int64

# %%
new_dataset.groupby('Class').mean()
# Out:
#                Time        V1        V2        V3        V4        V5  \
# Class
# 0.0    74435.987805 -0.166427 -0.081023  0.233958  0.105593 -0.192843
# 1.0    62781.541985 -5.579849  4.152674 -7.660395  4.742284 -4.017895
#
#              V6        V7        V8        V9  ...       V20       V21  \
# Class                                          ...
# 0.0    0.014819 -0.058388  0.069546 -0.022321  ... -0.007064 -0.009412
# 1.0   -1.396601 -6.509509  0.663476 -2.748126  ...  0.394684  0.778507
#
#             V22       V23       V24       V25       V26       V27       V28  \
# Class
# 0.0   -0.045028 -0.052143 -0.038799 -0.003583 -0.010906 -0.004191 -0.001111
# 1.0   -0.012563 -0.048989 -0.065777  0.065806  0.038768  0.180565  0.059636
#
#            Amount
# Class
# 0.0     91.622398
# 1.0    123.386005
#
# [2 rows x 30 columns]

# %%
X = new_dataset.drop(columns='Class', axis=1)
Y = new_dataset['Class']

# %%
print(X)
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# 91455    63477.0  1.255277 -0.029495 -0.427761 -0.276025  0.231572 -0.313201
# 102956   68440.0 -0.744489 -0.797113  0.841611 -1.197308 -0.228458  1.584461
# 141668   84458.0  1.249586 -0.469644  0.852798 -0.722207 -1.330126 -0.832319
# 101032   67704.0 -1.374367  0.360591  1.382047 -0.247018  0.971973 -1.209651
# 172399  121085.0  0.518281 -3.238157 -0.902286  0.072038 -1.947966 -0.095814
# ...          ...       ...       ...       ...       ...       ...       ...
# 203328  134769.0 -0.967767  2.098019 -5.222929  6.514573 -4.187674  2.114178
# 203700  134928.0  1.204934  3.238070 -6.010324  5.720847  1.548400 -2.321064
# 204064  135095.0  0.232512  0.938944 -4.647780  3.079844 -1.902655 -1.041408
# 204079  135102.0  1.862102 -0.124052 -1.989752  0.382609  0.473032 -0.674517
# 204503  135314.0 -3.158990  1.765452 -3.390168  0.987410 -1.509930 -1.280952
#
#               V7        V8        V9  ...       V20       V21       V22  \
# 91455   0.235763 -0.095670 -0.224640  ...  0.051805 -0.444711 -1.473184
# 102956 -1.475569  1.034018 -3.032910  ... -0.099725  0.161359  0.703665
# 141668 -0.685765  0.064123  2.075202  ... -0.229704 -0.035011  0.068770
# 101032  0.474821 -0.173709 -0.379265  ... -0.179688 -0.288769 -0.877648
# 172399  0.035845 -0.018156  1.879957  ...  1.274277  0.238414 -0.721282
# ...          ...       ...       ...  ...       ...       ...       ...
# 203328  0.948701 -2.448427 -3.203666  ...  1.147204 -0.843268  0.796739
# 203700 -0.781880  0.076619 -2.976249  ...  0.338161  0.098341 -0.845866
# 204064 -1.020407  0.547069 -1.105990  ...  1.141615  0.911373  1.042929
# 204079  0.298621 -0.282416  0.802053  ...  0.150727 -0.204158 -0.511441
# 204503 -2.719557  0.718325 -1.660183  ... -0.022590  1.120533  1.605085
#
#              V23       V24       V25       V26       V27       V28  Amount
# 91455   0.016064 -0.820126  0.203886  0.672954 -0.115865 -0.011019   50.99
# 102956  0.138748 -1.350605 -0.877216  0.080610  0.157713 -0.011177   25.00
# 141668 -0.022788  0.307701  0.451822 -0.677565  0.082783  0.031181    1.00
# 101032 -0.008286 -0.009295  0.390954  0.030655 -0.326106  0.100725    0.89
# 172399 -0.280999  0.133244 -0.875198  0.302690 -0.164238  0.071632  750.00
# ...          ...       ...       ...       ...       ...       ...     ...
# 203328  1.314312 -0.352887 -1.770706  0.098133  0.956769  0.162777  925.31
# 203700 -0.031228  0.421146  0.388361  0.056035  0.491828  0.340847    0.00
# 204064  0.999394  0.901260 -0.452093  0.192959  0.180859 -0.029315  345.00
# 204079  0.077874  0.388335  0.007896 -0.120980 -0.019579  0.006155  108.51
# 204503 -0.618637 -0.251283 -0.240528 -0.004327 -0.235477  0.018129   84.28
#
# [885 rows x 30 columns]

# %%
print(Y)
# Out:
# 91455     0.0
# 102956    0.0
# 141668    0.0
# 101032    0.0
# 172399    0.0
#          ...
# 203328    1.0
# 203700    1.0
# 204064    1.0
# 204079    1.0
# 204503    1.0
# Name: Class, Length: 885, dtype: float64

# %% [markdown]
# Split the data into Training data & Testing Data

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, stratify=Y, random_state=2)

# %%
print(X.shape, X_train.shape, X_test.shape)
# Out:
# (885, 30) (708, 30) (177, 30)

# %% [markdown]
# Model Training

# %% [markdown]
# Logistic Regression

# %%
model = LogisticRegression()

# %%
# training the Logistic Regression Model with Training Data
model.fit(X_train, Y_train)
# Out:
# LogisticRegression()

# %% [markdown]
# Model Evaluation

# %% [markdown]
# Accuracy Score

# %%
# accuracy on training data
X_train_prediction = model.predict(X_train)
training_data_accuracy = accuracy_score(X_train_prediction, Y_train)

# %%
print('Accuracy on Training data : ', training_data_accuracy)
# Out:
# Accuracy on Training data :  0.9548022598870056

# %%
# accuracy on test data
X_test_prediction = model.predict(X_test)
test_data_accuracy = accuracy_score(X_test_prediction, Y_test)

# %%
print('Accuracy score on Test Data : ', test_data_accuracy)
# Out:
# Accuracy score on Test Data :  0.9265536723163842
